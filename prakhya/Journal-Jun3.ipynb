// %% [markdown]
// .ts extension
//
// running the TypeScript compiler will result in a javascript file you fed in
//
// Type annotations - lightweight recording of intended contract of the function/variable. In this case, we intend the greeter function to be called with a single string parameter. Try changing call greeter to pass an array instead:
//
// function greeter(person: string) {
//     return "Hello, " + person;
// }
//
// var user = [0, 1, 2];
//
// document.body.innerHTML = greeter(user);
//
// error:
//
// greeter.ts(7,26): Supplied parameters do not match any signature of call target
//
// removing all arguments to geeter call -> notification that called this f(X) with an unexpected # of parameters
//
// can offer static analysis based on code structure and type annotations
//
// can use typescript even w/errors (but maybe warning that code likely won't run as expected)
//
// interface that describes objects that have a firstName and lastName field
//
// two types are compatible if their internal structure is compatible
//
// implement an interface just by having the shape the interface requires, without an explicit implements clause:
//
// interface Person {
//     firstName: string;
//     lastName: string;
// }
//
// function greeter(person: Person) {
//     return "Hello, " + person.firstName + " " + person.lastName;
// }
//
// var user = { firstName: "Jane", lastName: "User" };
//
// document.body.innerHTML = greeter(user);
//
// supports new features in JavaScript, like support for class-based object-oriented programming
//
// classes and interfaces play well together, letting the programmer decide on the right level of abstraction
//
// use of public on arguments to the constructor is a shorthand that allows us to automatically create properties with that name:
//
// class Student {
//     fullName: string;
//     constructor(public firstName, public middleInitial, public lastName) {
//         this.fullName = firstName + " " + middleInitial + " " + lastName;
//     }
// }
//
// interface Person {
//     firstName: string;
//     lastName: string;
// }
//
// function greeter(person : Person) {
//     return "Hello, " + person.firstName + " " + person.lastName;
// }
//
// var user = new Student("Jane", "M.", "User");
//
// document.body.innerHTML = greeter(user);
//
// Re-run tsc greeter.ts and generated JavaScript is same as earlier code. Classes in TypeScript are just a shorthand for the same prototype-based OO frequently used in JavaScript.
//
//
// TypeScript has always been to make writing JavaScript projects a clean, easy, and simple process
// https://blogs.msdn.microsoft.com/typescript/2016/05/10/making-new-typescript-projects-a-breeze/
//
// ran code in playground that prints out "Hello, Jane User"
// document.body.innerHTML = greeter(user);
// hovering over geeter says function's signature, the func geeter line
// takes the fullName which has the constructor made up of 3 arguments
// the interface is person
// creates variable user and new instance of class\
// https://www.typescriptlang.org/play/
//
// knockout - web framework - standalone JavaScript implementation of the Model-View-ViewModel pattern with templates
//
//     a clear separation between domain data, view components and data to be displayed
//     the presence of a clearly defined layer of specialized code to manage the relationships between the view components
//
//     latter leverages the native event management features of the JavaScript language.
//
//     These features streamline and simplify the specification of complex relationships between view components, which in turn make the display more responsive and the user experience richer
//
//      command shell for interactive computing in multiple programming languages, originally developed for the Python programming language, that offers introspection, rich media, shell syntax, tab completion, and history. IPython provides the following features:
//
//     Interactive shells (terminal and Qt-based).
//     A browser-based notebook with support for code, text, mathematical expressions, inline plots and other media.
//     Support for interactive data visualization and use of GUI toolkits.
//     Flexible, embeddable interpreters to load into one's own projects.
//     Tools for parallel computing.
// JupyterHub is a server that gives multiple users access to Jupyter notebooks, running an independent Jupyter notebook server for each user.
//
// wiki:
// class Person {
//     private name: string;
//     private age: number;
//     private salary: number;
//
//     constructor(name: string, age: number, salary: number) {
//         this.name = name;
//         this.age = age;
//         this.salary = salary;
//     }
//
//     toString(): string {
//         return `${this.name} (${this.age}) (${this.salary})`; // As of version 1.4
//     }
// }
// supports ECMAScript 6 classes that integrate the optional type annotations support
// https://code.visualstudio.com/Docs/languages/typescript
// floating point numbers get the type number. In addition to hexadecimal and decimal literals, TypeScript also supports binary and octal literals introduced in ECMAScript
// javascript threading/parallel processing
//
// array types can be written in one of two ways. In the first, you use the type of the elements followed by [] to denote an array of that element type or Array<elemType>
//
// Tuple types allow you to express an array where the type of a fixed number of elements is known, but need not be the same. For example, you may want to represent a value as a pair of a string and a number
//
// enum is a way of giving more friendly names to sets of numeric values
//
// in browser- possibly no warnings given
//
// xcode, treehouse

// %% [markdown]
// typescript notebook ready that I could make lessons in
