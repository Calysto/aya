// %%
return (function (a = 1, b = 2) { return a === 3 && b === 2; }(3));
// Out:
// execute@https://athena.brynmawr.edu/jupyter/user/pmalyala/kernelspecs/jskernel/kernel.js?v=20160613104332:53:17
// CodeCell.prototype.execute@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:21675:28
// Notebook.prototype.execute_cell_and_select_below@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:27190:13
// _actions["run-cell-and-select-next"].handler@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:30167:17
// @https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:30673:25
// ActionHandler.prototype.call@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:30775:16
// ...

// %% [markdown]
// default values of parameters: defaults are evaluated on every function execution

// %%
function foo(x = []) {
  x.push(1);
  console.log(x);
}
 
foo(); // [1]
foo(); // [1]
foo(); // [1]
// Out:
// 1
// 1
// 1

// %%
var x = 1;
 
function foo(x, y = x) {
  console.log(y);
}
 
foo(2); // 2, not 1!
// Out:
// 2

// %%
const obj = { first: 'Jane', last: 'Doe' };
const {first: f, last: l} = obj;
    // f = 'Jane'; l = 'Doe'

// {prop} is short for {prop: prop}
const {first, last} = obj;
    // first = 'Jane'; last = 'Doe'

// %%
const obj = { foo: 123 };

const {writable, configurable} =
    Object.getOwnPropertyDescriptor(obj, 'foo');

console.log(writable, configurable); // true true
// Out:
// true true

// %%
function multiply(a, b = 1) {
  return a*b;
}

multiply(5); // 5
// Out:
// 5

// %%
//ecmascript6 because ts isn't implemented

// %%
import pycurl
from io import BytesIO

function sayHello () {return __get__ (this, function (ipAddress, port){
    
});}
    buffer = BytesIO()
c = pycurl.Curl()
c.setopt(c.URL, ipAddress+ ':' + port +'/')
c.setopt(c.WRITEDATA, buffer)
c.perform()
c.close()
body = buffer.getvalue()
# Body is a byte string.
# We have to know the encoding in order to print it to a text file
# such as standard output.
console.log(body.decode('iso-8859-1');

// %%
var xmlHttp = new jQuery.XMLHttpRequest();
xmlHttp.open( "GET", "http://165.106.125.70:3000/", false ); // false for synchronous request
xmlHttp.send( null );
console.log(xmlHttp.responseText);
// Out:
// @https://athena.brynmawr.edu/jupyter/user/pmalyala/kernelspecs/jskernel/kernel.js?v=20160613104332 line 53 > eval:1:19
// execute@https://athena.brynmawr.edu/jupyter/user/pmalyala/kernelspecs/jskernel/kernel.js?v=20160613104332:53:17
// CodeCell.prototype.execute@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:21675:28
// Notebook.prototype.execute_cell_and_select_below@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:27190:13
// _actions["run-cell-and-select-next"].handler@https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:30167:17
// @https://athena.brynmawr.edu/jupyter/user/pmalyala/static/notebook/js/main.min.js?v=1c2abb797e9945d6ce7d58ae051fe985:30673:25
// ...

// %%
response = $.get("//165.106.125.70:3000/");
// Out:
// [object Object]

// %%
response.statusText
// Out:
// error

// %% [markdown]
// request webpage from js
// https://learn.jquery.com/ajax/
// https://search.yahoo.com/yhs/search?p=jquery+XMLHttpRequest&ei=UTF-8&hspart=mozilla&hsimp=yhs-004
// http://stackoverflow.com/questions/247483/http-get-request-in-javascript
